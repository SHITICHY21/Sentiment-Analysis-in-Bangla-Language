# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/val.csv
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/train.csv
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/test.csv
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100076.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g349.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3750.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2008.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100090.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2081.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/480949_508279742562900_99236165_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g420.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4489.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3138.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3417.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/319278011_2354026461432681_7268156464878739058_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1786.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2907.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/119697552_10220629952873141_5359833052858936147_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g270.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1075.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3501.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2863.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/771.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/208.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000130.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4125.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2628.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3363.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4009.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/331397102_1363102231206845_7327634731822640165_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9009.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/317239641_8247466971993388_5230186546953611333_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3228.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/217724457_3916104801829211_1064565496789113192_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/473.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3446.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/285458213_4881261251980223_4249783104884821829_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1792.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2936.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2029.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1411.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3532.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2675.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g294.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4765.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g147.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1749.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1501.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g242.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2021.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/339253307_529764995777435_3868197215714514191_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g301.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8016.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1995.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1385.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3651.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4398.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4581.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3537.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000029.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/268797280_247938897440512_6533329627332762005_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g330.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9083.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3807.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100065.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/333.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1354.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1024.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/537.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3014.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g471.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2375.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000009.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000061.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/369.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/56.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000076.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g237.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/654.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g135.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/89.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000075.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/20.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4351.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/317802469_2483516935138001_5156545718504768775_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000066.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/275.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3670.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2532.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1161.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g290.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/5018.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3645.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1777.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1380.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/239.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2057.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1009.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3295.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000138.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1381189_10151702235033837_2098371968_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g375.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/274922914_296303572604044_3993548539943705030_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2094.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/58.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000021.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3816.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2695.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1304.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/128064521_921729001567050_8493564428231049746_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g38.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1340.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g412.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2028.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/150.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2137.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/6.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3364.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2654.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3310.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3209.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2319.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/149.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1488.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/298340991_398663165701417_2244084262259515778_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2640.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4373.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/187.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g448.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/521.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/436.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/76.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/539.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3330.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000088.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2844.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3732.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1355.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/355.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/315296156_585848863350287_4918112074020124356_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/336142951_1281267202824105_3250583881651727657_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8024.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2899.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2041.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3546.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/516.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9022.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/71.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100039.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/708.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3539.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3743.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g69.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8058.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/474.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g402.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1840.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3574.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/98331044_3111011175611423_5647207959252434944_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9097.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000079.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3207.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g132.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/317662135_3402223533368645_7432541391553752184_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/5003.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2580.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3280.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8027.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8032.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/501.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1395.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3823.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3467.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2363.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3562.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/915.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/815.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3654.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/339481998_2373482076167699_3478350488637763364_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/62104229_348408459178462_6104613150118641664_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/317320585_226115199747303_7830466033725494353_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/760.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9033.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/58895139_419903332157481_7595062948968529920_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2704.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/817.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2003.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/285443737_356378859929848_3885622464372317533_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3802.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4706.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/429.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000120.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3684.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1055.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2560.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/271766548_268701915364210_7355337615700778196_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/158050633_1401465676864558_2390761395133308535_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2753.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/682.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g22.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1548.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4369.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3198.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3322.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1934.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/544.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1715.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2953.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/377.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2866.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4843.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/272.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/795.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4597.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/270.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g326.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3221.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/182.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3884.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100072.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1936.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/269422536_249775087256893_2016554150581599843_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4405.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3713.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g218.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3195.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/215.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2067.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g400.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8033.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2558.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/489.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/576.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3828.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100064.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2571.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000023.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1834.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2749.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8071.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2526.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/185.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4320.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4355.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3064.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2751.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/613.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/243.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000094.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g284.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g176.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4021.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2748.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/288640106_4914654558640892_3391142581861767912_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3494.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2510.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4611.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3366.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1010.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3577.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/153.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/94357394_10222392619154422_2706061994728882176_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100080.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2743.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/703.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2852.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/341255255_459365139707168_6969274826036770996_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/189.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4033.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000008.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/143.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g239.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2719.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g200.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/36766195_2062522417335255_1531211039943688192_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3534.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3724.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2444.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3085.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3347.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/476.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2403.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/317949364_703473734456165_8872254921450696760_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g399.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/153969503_271717271200217_6791713521298575983_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8040.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2626.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3497.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2982.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000047.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/339145603_169897315553898_1344755150338508460_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8086.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000049.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2716.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3260.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9086.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3708.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g272.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3382.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3616.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/267696182_239810074954208_2962978352529902044_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4016.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000057.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/327.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3769.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1669.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/253.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g51.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g328.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8080.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2673.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/343.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8043.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000099.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2643.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4076.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/115.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4035.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/131.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g232.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4735.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2087.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1058.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/446.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1812.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9014.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/317854666_1914028675595507_8993971075817596459_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3010.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/626.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2997.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000121.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3323.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2150.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100118.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/289156396_4926324857473862_2729921420349851184_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/425.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/5.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g354.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1559.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g44.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/366.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2809.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2530.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2922.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3493.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1101.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/850.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100032.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100009.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4038.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2897.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/128118662_1785638828253646_3786895367349225521_n (1).jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000010.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/885.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2789.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4749.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4077.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3318.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/151.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1097.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/287664313_4910327485740266_7280837081599711470_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8087.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2552.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8010.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1376.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2655.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3164.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000060.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/426.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/732.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/503.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2573.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g355.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2011.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/317885390_6687994481216342_3601716433693185969_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2131.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g263.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2471.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1413.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2984.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2928.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2608.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2595.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g227.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g73.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4357.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100012.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/270127884_255820389985696_6979273000514492994_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000048.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/622.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1129.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3454666777777888811122333300_n.PNG
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2501.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2323.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2627.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8089.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/318309037_5973660049361585_5718608421673904729_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100094.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/106777925_179379823558631_6431708429080901456_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1655.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4447.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3755.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g258.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3730.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000069.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2795.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g64.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/5012.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g159.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/440.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4853.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/260.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g368.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9055.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000082.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/240829183_177553044479098_6231337548214577609_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/322702734_489080213369564_1708747884752546994_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1716.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3522.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9047.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3037.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3305.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4539.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3284.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3243.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/534.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3395.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3302.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/202.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3726.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4338.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/84.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4004.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/577.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3768.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4074.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2698.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/944.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/47574792_192082345070448_2058646827917377536_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3623.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/237.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/273.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4215.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/286.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1032.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3218.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4578.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/341633812_975376666789122_8882282822010474464_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/283.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/486.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2338.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/513.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g9.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/150284221_3507509912688845_1431403829616363582_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9025.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g295.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3461.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/766.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2460.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/85.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/5010.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100060.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2902.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000035.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/118773373_2969448959828138_7897793116632194645_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100121.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/564.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9079.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/359.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3058.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/67.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3949.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g128.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1709.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8085.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000058.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/289036852_4915646765208338_4228701507032232628_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2998.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2725.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3465.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2505.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/289.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2020.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1331.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g260.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9031.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3242.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4324.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/52595768_596005614246651_3797632240859480064_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2587.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g340.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3298.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000072.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100027.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3722.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2537.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4646.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2633.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000071.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3358.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3114.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3303.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000122.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3377.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/118.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4492.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/15826763_1812327895683989_8789029654525626929_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2842.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100104.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3288.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3030.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8020.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/768.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/361.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1089.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3981.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000074.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4057.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/591.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3941.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2091.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/185421716_3918568714916153_8598063927261511848_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/17879980_1699083827050958_9200579015576879330_o.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3394.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3179.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/321740372_742362124156542_2496430397786047619_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2890.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/172570003_3638894539550240_9070484307748435415_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/82.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000042.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2564.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1795.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/723.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2475.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g148.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3016.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3543.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3566.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3109.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2555.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/443.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/295.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2596.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3215.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2168.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/325926262_1409186462951278_8911196955066516502_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/176.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3119.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100017.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1475.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1554.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/278494908_1719873822129739_5912487895510004725_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2139.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g70.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3017.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000039.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3122.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g20.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g426.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1499.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2993.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/279.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3791.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2782.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3488.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8064.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2812.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/5017.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/757.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2718.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/311428096_632900294868949_251178584434446235_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/30.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/97.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/316954224_508496901315978_718864686604544170_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g66.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/274619783_4604011356371882_1883313924922023242_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g439.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/334.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/106.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4251.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3808.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4206.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g190.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2980.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g257.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3656.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g336.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2696.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g231.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/30420836_2115277768745748_6047598464514934067_o.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/163.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4267.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/184401612_3705602962879397_7221300735975586832_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4370.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4413.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2386.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4620.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g89.jpg
# ...
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/423.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2566.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3738.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100095.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/121438685_4556916274379396_8063434313070166247_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1204.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3988.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9077.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g168.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3820.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3540.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1374119_10153327692545725_1495228078_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3930.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3042.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3572.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/307.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1057.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/593.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g250.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1322.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3673.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/504.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2504.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/129.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3307.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/735.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/875.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3954.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/Screenshot 2023-04-20 at 3.34.16 PM.png
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000070.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100093.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/205.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3237.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/10435029_10152529770948843_98908688854090658_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g120.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3154.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2586.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3022.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/422.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3187.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9002.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g3.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4296.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/133.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g142.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2686.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/324349699_1620619105054862_463773899976827284_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/304.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g331.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8066.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g118.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3126.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1379.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1581.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9043.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/167107655_3593113994128295_4749548695589725161_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/333657386_3449779385267869_7082237690998681667_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3667.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2320.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9095.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/317815297_2211276962415714_2802084358674083523_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3784.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1970.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3875.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1090.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1358.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g293.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/320875509_1168789253760691_6014263896342841464_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/810.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/989.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1994.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8001.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100114.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2313.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1323.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9032.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3415.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4412.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3206.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3315.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/13680989_1832949233599488_8906464272025782596_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1445.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2788.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100010.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/318852473_705868644586670_6483175506458192373_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/285729231_4882720775167604_3965634496495432355_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2772.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/218.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3767.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/635.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3545.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8005.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000027.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/249.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1883.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3174.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/213.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2026.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1698.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/272013933_267142838853451_8158103244062354052_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3617.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3070.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2088.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/431.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3340.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2322.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3137.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100028.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3511.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/597.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g187.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3734.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4101.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/320628_10150375239150753_366331419_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9012.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4186.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2832.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000063.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3031.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000006.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g5.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/60339634_3095720303773244_3667926040996478976_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000005.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/461.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1923.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1021.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/136.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4203.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3706.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1861.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000002.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3536.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/60815736_337433590275949_198322077692854272_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2151.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1976.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1141.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g387.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3737.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3496.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2861.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2769.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2710.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3774.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/944680_1724041577809938_6506086756718224026_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3882.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2092.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3349.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g403.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2884.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3695.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/925.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/9001.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1903.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7100018.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2689.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/8000114.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3613.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4678.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3495.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/454.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2607.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/605.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/754.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g437.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/364.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2691.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/90.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g86.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/599.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/25.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/4490.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/245178363_4147299702043052_2024926989974493414_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3267.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/7000090.jpeg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/319405556_1416019932268337_5965709344536218894_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3120.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/323442265_6376858492343543_6760931927501827914_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2867.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g6.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/1979.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/82241866_3247281331967180_4395861493736800256_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3059.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3410.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2085.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g475.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/147.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/79537251_2435091703417191_6288266767739387904_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/i_m_g107.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/325907615_904745250571460_8683632061422944318_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/921.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3950.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/315076025_2380513328756691_4419138248032757693_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/728.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/133570912_233915131576268_6625977872465576351_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/240389860_180094897558246_8452324926852903009_n.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/3361.jpg
# /kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/2599.jpg

# %%
import pandas as pd

# Define file paths
dataset_path = "/kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/"
train_csv = dataset_path + "train.csv"
val_csv = dataset_path + "val.csv"
test_csv = dataset_path + "test.csv"

# %%
# Load the CSV files into pandas DataFrames
train_df = pd.read_csv(train_csv)
val_df = pd.read_csv(val_csv)
test_df = pd.read_csv(test_csv)

# Show the first few rows
print("Train Data Sample:")
print(train_df.head())

print("\nValidation Data Sample:")
print(val_df.head())
# Out:
# Train Data Sample:
#   image_name                                           Captions  \
# 0    205.jpg  নির্বোধ দেখার এবং আপনি যে যত্নশীল তা না করার ক...
# 1    209.jpg  একটি বোর্ডার আর্ম স্কেটার একটি আমন্ত্রণ উপার্জ...
# 2    210.jpg       যদি শরীর দুর্বল হয় তবে মন শক্তিশালী হবে না।
# 3    215.jpg  একজন ধার্মিক ব্যক্তির কার্যকর উত্সাহ প্রার্থনা...
# 4    222.jpg                                          অসমাপ্ত ?
#
#   Label_Sentiment  Label
# 0           other      6
# 1           other      6
# 2           other      6
# 3           other      6
# 4           other      6
#
# Validation Data Sample:
#   image_name                                           Captions  \
# 0   4679.jpg           আর্কটিসেক্সপ্লোরারের সাথে বাণিজ্য সমাপ্ত
# 1   4685.jpg  কে মুর এনআইএসডি নেতৃত্বের পশ্চাদপসরণে জেলা নেত...
# 2   4686.jpg  বিজ্ঞানীরা ত্রুটিযুক্ত রাসায়নিক রিএজেন্টের বি...
# 3   4687.jpg  একটি নতুন জরিপে বলা হয়েছে ট্রাম্প বিশেষত সুইং...
# 4   4691.jpg  ডেভ গ্রহল এবং কার্ট কোবাইন স্মার্ক যখন একটি ঝল...
#
#   Label_Sentiment  Label
# 0           other      6
# 1           other      6
# 2           other      6
# 3           other      6
# 4           other      6

# %%
print("Train Data Info:")
print(train_df.info())
# Out:
# Train Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3833 entries, 0 to 3832
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   image_name       3833 non-null   object
#  1   Captions         3833 non-null   object
#  2   Label_Sentiment  3833 non-null   object
#  3   Label            3833 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 119.9+ KB
# None

# %%
print("Missing values in Train dataset:\n", train_df.isnull().sum())
print("\nMissing values in Validation dataset:\n", val_df.isnull().sum())
# Out:
# Missing values in Train dataset:
#  image_name         0
# Captions           0
# Label_Sentiment    0
# Label              0
# dtype: int64
#
# Missing values in Validation dataset:
#  image_name         0
# Captions           0
# Label_Sentiment    0
# Label              0
# dtype: int64

# %%
print("Unique Sentiments in Train Dataset:", train_df["Label_Sentiment"].unique())
print("Label Distribution:\n", train_df["Label_Sentiment"].value_counts())
# Out:
# Unique Sentiments in Train Dataset: ['other' 'surprise' 'sad' 'fear' 'disgust' 'angry' 'happy']
# Label Distribution:
#  Label_Sentiment
# happy       861
# other       716
# sad         621
# angry       477
# surprise    410
# fear        400
# disgust     348
# Name: count, dtype: int64

# %%
print(f"Train Data Shape: {train_df.shape}")
print(f"Validation Data Shape: {val_df.shape}")
print(f"Test Data Shape: {test_df.shape}")
# Out:
# Train Data Shape: (3833, 4)
# Validation Data Shape: (414, 4)
# Test Data Shape: (414, 4)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.countplot(x=train_df['Label_Sentiment'], order=train_df['Label_Sentiment'].value_counts().index)
plt.xticks(rotation=45)
plt.title("Sentiment Distribution in Train Data")
plt.show()

# %%
for sentiment in train_df['Label_Sentiment'].unique():
    sample_text = train_df[train_df['Label_Sentiment'] == sentiment]['Captions'].sample(1).values[0]
    print(f"{sentiment.upper()} → {sample_text}\n")
# Out:
# OTHER → "আপনি কি ক্র্যাবি প্যাটি তৈরি করতে চান?"
#
# SURPRISE → বাচ্চাদের আজ টোপ-টেক পণ্যগুলি ভালবাসে! হাঃ হাঃ হাঃ
#
# SAD → আমি সবাই পছন্দ করছি, আমি আপনাকে সর্বদা খালি করার জন্য দুঃখিত ওয়ালেট
#
# FEAR → আমি অত্যন্ত আতঙ্কিত. কেউ যদি আমাকে কষ্ট দিতে আসে?
#
# DISGUST → Bro শ্বরের উপর ভাই এই খোঁচা খেতে যেতেন ??
#
# ANGRY → হিজড়া বাচ্চারা তারা কে সে সম্পর্কে বিভ্রান্ত হয় না, তাই থামুন
#
# HAPPY → জ্যাক আজ রাতে প্রথমবারের মতো সিড স্কোর দেখেছে!

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import seaborn as sns
import matplotlib.pyplot as plt

# Ensure there are no missing values
train_df['Captions'] = train_df['Captions'].fillna("").astype(str)

# Compute text lengths
train_df['text_length'] = train_df['Captions'].apply(lambda x: len(x.split()))

plt.figure(figsize=(8,5))
sns.histplot(train_df['text_length'], bins=30, kde=True)
plt.title("Distribution of Text Lengths")
plt.xlabel("Number of Words in Captions")
plt.show()

# %%
print("Total Unique Images in Train Data:", train_df['image_name'].nunique())
print("Total Images in Dataset:", train_df.shape[0])
# Out:
# Total Unique Images in Train Data: 3832
# Total Images in Dataset: 3833

# %%
# !apt-get update
# !apt-get install fonts-noto-cjk fonts-noto-color-emoji fonts-noto-ui-core -y

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# Set Bengali font explicitly
bengali_font_path = "/usr/share/fonts/truetype/noto/NotoSansBengaliUI-Regular.ttf"
bengali_font = fm.FontProperties(fname=bengali_font_path)

# Apply the font globally for Bengali
plt.rcParams["font.family"] = bengali_font.get_name()
plt.rcParams["axes.unicode_minus"] = False  # Fix minus sign issues

print("✅ Using Bengali Font:", bengali_font.get_name())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-4426090f752a> in <cell line: 9>()
#       7
#       8 # Apply the font globally for Bengali
# ----> 9 plt.rcParams["font.family"] = bengali_font.get_name()
#      10 plt.rcParams["axes.unicode_minus"] = False  # Fix minus sign issues
#      11
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/font_manager.py in get_name(self)
#     662         Return the name of the font that best matches the font properties.
#     663         """
# --> 664         return get_font(findfont(self)).family_name
#     665
#     666     def get_style(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     295                 f"for the old name will be dropped %(removal)s.")
#     296             kwargs[new] = kwargs.pop(old)
# --> 297         return func(*args, **kwargs)
#     298
#     299     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/font_manager.py in get_font(font_filepaths, hinting_factor)
#    1521         hinting_factor = mpl.rcParams['text.hinting_factor']
#    1522
# -> 1523     return _get_font(
#    1524         # must be a tuple to be cached
#    1525         paths,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/font_manager.py in _get_font(font_filepaths, hinting_factor, _kerning_factor, thread_id)
#    1462 def _get_font(font_filepaths, hinting_factor, *, _kerning_factor, thread_id):
#    1463     first_fontpath, *rest = font_filepaths
# -> 1464     return ft2font.FT2Font(
#    1465         first_fontpath, hinting_factor,
#    1466         _fallback_list=[
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/share/fonts/truetype/noto/NotoSansBengaliUI-Regular.ttf'

# %%
import random
from PIL import Image
import os
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import textwrap  # For wrapping long text

image_folder = "/kaggle/input/sentiment-analysis-in-bangla/1704054_Dataset/Images/"

# Set Bengali font
bengali_font_path = "/usr/share/fonts/truetype/noto/NotoSansBengaliUI-Regular.ttf"
bengali_font = fm.FontProperties(fname=bengali_font_path)

# Select random samples
samples = train_df.sample(3)

plt.figure(figsize=(15, 8))  # Increased figure size
for i, row in enumerate(samples.itertuples(), 1):
    img_path = os.path.join(image_folder, row.image_name)
    
    img = Image.open(img_path)

    plt.subplot(1, 3, i)
    plt.imshow(img)
    
    # Sentiment Label (English Text)
    plt.text(0.5, 1.15, f"Sentiment: {row.Label_Sentiment}", 
             fontsize=16, ha='center', va='top', transform=plt.gca().transAxes)

    # Wrap Long Bengali Captions (50 characters per line)
    wrapped_caption = "\n".join(textwrap.wrap(f"ক্যাপশন: {row.Captions}", width=50))

    # Display Caption Below Image
    plt.text(0.2, -0.2, wrapped_caption, fontproperties=bengali_font,
             fontsize=14, ha='center', va='top', transform=plt.gca().transAxes)

    plt.xticks([])
    plt.yticks([])
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# Set a font that supports both English & Bengali
bengali_font_path = "/usr/share/fonts/truetype/noto/NotoSansBengaliUI-Regular.ttf"
universal_font_path = "/usr/share/fonts/truetype/noto/NotoSansCJK-Regular.ttc"  # Change if needed

# Check which font exists
try:
    font_path = universal_font_path  # Prefer universal font
    font_name = fm.FontProperties(fname=font_path).get_name()
except:
    font_path = bengali_font_path  # Fallback to Bengali-only font
    font_name = fm.FontProperties(fname=font_path).get_name()

print("✅ Using Font:", font_name)

# Merge all text captions into one string
all_text = " ".join(train_df["Captions"].dropna())  # Drop NaN values if any

# Generate WordCloud
wordcloud = WordCloud(
    font_path=font_path,  
    width=1000, height=500, 
    background_color="white",
    colormap="viridis",
    collocations=False  # Prevents duplicate words appearing larger
).generate(all_text)

# Plot WordCloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Most Common Words in Bengali Captions", fontproperties=fm.FontProperties(fname=font_path), fontsize=16)
plt.show()

# %%
import cv2
import numpy as np

def preprocess_image(image_path):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))  # Resizing to standard size
    img = img / 255.0  # Normalization
    return img

# Test on one image
sample_image = preprocess_image(image_folder + train_df["image_name"].iloc[0])

plt.imshow(sample_image)
plt.axis("off")
plt.title("Preprocessed Image")
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

MAX_VOCAB_SIZE = 10000  # Top 10,000 words
MAX_SEQ_LENGTH = 30  # Max words in a caption

# Tokenize text
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, oov_token="<OOV>")
tokenizer.fit_on_texts(train_df["Captions"])

# Convert text to sequences
text_sequences = tokenizer.texts_to_sequences(train_df["Captions"])

# Pad sequences
padded_text = pad_sequences(text_sequences, maxlen=MAX_SEQ_LENGTH, padding="post", truncating="post")

print("Example Tokenized Text:", text_sequences[0])
print("Padded Text Shape:", padded_text.shape)

# %%
pip install tensorflow transformers

# %%
from transformers import ViTFeatureExtractor, ViTModel
import torch
import cv2
import numpy as np

# Load ViT feature extractor & model
feature_extractor = ViTFeatureExtractor.from_pretrained("google/vit-base-patch16-224-in21k")
vit_model = ViTModel.from_pretrained("google/vit-base-patch16-224-in21k")

# Image Preprocessing Function
def preprocess_image(image_path):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    img = feature_extractor(images=img, return_tensors="pt")["pixel_values"]
    return img

# Test on one image
sample_img_path = image_folder + train_df["image_name"].iloc[0]
img_tensor = preprocess_image(sample_img_path)

# Extract features
with torch.no_grad():
    img_features = vit_model(img_tensor).last_hidden_state[:, 0, :]  # CLS Token Output

print("✅ ViT Feature Shape:", img_features.shape)  # Should be (1, 768)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Define text preprocessing parameters
MAX_VOCAB_SIZE = 10000  # Top 10,000 words
MAX_SEQ_LENGTH = 30  # Max words per caption

# Tokenize text
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, oov_token="<OOV>")
tokenizer.fit_on_texts(train_df["Captions"])

# Convert text to sequences
text_sequences = tokenizer.texts_to_sequences(train_df["Captions"])

# Pad sequences
padded_text = pad_sequences(text_sequences, maxlen=MAX_SEQ_LENGTH, padding="post", truncating="post")

print("✅ Padded Text Shape:", padded_text.shape)  # (num_samples, MAX_SEQ_LENGTH)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding, Concatenate, Flatten
import tensorflow as tf

# 1️⃣ Image Input (ViT)
image_input = Input(shape=(768,), name="image_input")

# 2️⃣ Text Input (LSTM)
text_input = Input(shape=(MAX_SEQ_LENGTH,), name="text_input")
embedding_layer = Embedding(input_dim=MAX_VOCAB_SIZE, output_dim=256, input_length=MAX_SEQ_LENGTH)(text_input)
lstm_layer = LSTM(128, return_sequences=False)(embedding_layer)

# 3️⃣ Concatenate Features
merged = Concatenate()([image_input, lstm_layer])

# 4️⃣ Dense Layers for Classification
dense1 = Dense(256, activation="relu")(merged)
dense2 = Dense(128, activation="relu")(dense1)
output = Dense(len(train_df["Label_Sentiment"].unique()), activation="softmax")(dense2)

# 5️⃣ Create Model
model = Model(inputs=[image_input, text_input], outputs=output)

# Compile Model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Summary
model.summary()

# %%
import numpy as np
from tqdm import tqdm

# Extract image features for all images
image_features = []
for img_name in tqdm(train_df["image_name"]):
    img_tensor = preprocess_image(image_folder + img_name)
    with torch.no_grad():
        img_feat = vit_model(img_tensor).last_hidden_state[:, 0, :].numpy()
    image_features.append(img_feat)

image_features = np.array(image_features).squeeze()  # (num_samples, 768)
text_inputs = np.array(padded_text)  # (num_samples, MAX_SEQ_LENGTH)
labels = train_df["Label"].values  # Convert sentiment labels

print("✅ Image Feature Shape:", image_features.shape)
print("✅ Text Feature Shape:", text_inputs.shape)
print("✅ Labels Shape:", labels.shape)

# %%
# Train the multimodal model
history = model.fit(
    [image_features, text_inputs], labels,
    validation_split=0.2,
    epochs=10,
    batch_size=32
)

# %%
# Evaluate on validation set
loss, accuracy = model.evaluate([image_features, text_inputs], labels)
print(f" Validation Accuracy: {accuracy:.4f}")

# Predict on a new sample
sample_idx = 10
sample_img_feat = image_features[sample_idx].reshape(1, -1)
sample_text_feat = text_inputs[sample_idx].reshape(1, -1)

predicted_label = np.argmax(model.predict([sample_img_feat, sample_text_feat]))
print(" Predicted Sentiment:", predicted_label)
